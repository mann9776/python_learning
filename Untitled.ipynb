# %%
password = 'mickey195@'
while True:
    pass_str = input('Enter your password" ')
    if pass_str == 'mickey195@':
        print('''Hello 
        you have successfully logged in''')
        break
    else:
        print('''Invalid input,
        Try again''')
# Out:
# Enter your password"  hygufyutjvbj
# Invalid input,
#         Try again
# Enter your password"  jhvbjhvb
# Invalid input,
#         Try again
# Enter your password"  mickey195@
# Hello
#         you have successfully logged in

# %%
str1 = '12345'

upper = lambda string: string.upper()
print(upper(str1))
# Out:
# 12345
